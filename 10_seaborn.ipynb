# %% [markdown]
# # Seaborn
#
# Seaborn is a Python data visualization library based on **matplotlib**. It provides a high-level interface for drawing attractive and informative statistical graphics.
#
# For a brief introduction to the ideas behind the library, you can read the [introductory notes](https://seaborn.pydata.org/introduction.html#introduction). You can browse the [example gallery](https://seaborn.pydata.org/examples/index.html#example-gallery) to see what you can do with seaborn, and then check out the [tutorial](https://seaborn.pydata.org/tutorial.html#tutorial) and [API reference](https://seaborn.pydata.org/api.html#api-ref) to find out how.

# %% [markdown]
# ```{note}
# You don't have to memorise all this. You should use this chapter as reference while working with seaborn and you want to explicitly control the aesthetics of your plot. You will hardly need to master everything we discuss in this chapter.
#
# Best way to master data visualization (rather anything) is to practice it. The more you use it, the more you know it better. Another thing that you must do is learn what each plot means and where it can be used. Application oriented approach towards visualization will give you better understanding of plots and data representation overall.
# ```

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Seaborn comes with built-in data sets, but need internet connection to download them for the first time.
#
# ```{note}
# Make sure you are connected to the internet before running the next cell.
# ```
#
# Here we are not using our dataset instead we will be using built-in dataset in `seaborn` library named as `tips` and `iris`.

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## Distribution Plots
#
# Distribution plots allow us to visualize the distribution of a data set. Pretty straight forward, huh?
#
# - Distplot
# - Jointplot
# - Pairplot
# - Kdeplot

# %% [markdown]
# ### Distplot
#
# The Displot shows the distribution of a univariate set of observations.

# %%
sns.displot(tips['total_bill']);

# %% [markdown]
# ### Jointplot
#
# Jointplot allows you to basically match up two distplots for bivariate data. With your choice of what **kind** parameter to compare with. *scatter*, *reg*, *resid*, *kde*, *hex*, etc. are all the possible values that you can use.

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='scatter')

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex')

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='reg')

# %% [markdown]
# ### Pairplot
#
# Pairplot will plot pairwise relationships across an entire dataframe (for the numerical columns) and supports a color hue argument (for categorical columns).

# %%
sns.pairplot(iris)

# %%
sns.pairplot(tips,hue='time', palette='coolwarm')

# %% [markdown]
# ### Kdeplot
#
# Kdeplots are [Kernel Density Estimation plots](http://en.wikipedia.org/wiki/Kernel_density_estimation#Practical_estimation_of_the_bandwidth). These KDE plots replace every single observation with a Gaussian (Normal) distribution centered around that value. For example:

# %%
sns.kdeplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ## Categorical Data Plots
#
# Now let's discuss using seaborn to plot categorical data!
#
# * barplot
# * countplot
# * boxplot
# * violinplot
# * stripplot
# * swarmplot

# %% [markdown]
# ### Barplot
#
# These very similar plots allow you to get aggregate data off a categorical feature in your data. **Barplot** is a general plot that allows you to aggregate the categorical data based off some function, by default the mean:

# %%
sns.barplot(x='sex', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# You can change the estimator object to your own function, that converts a vector to a scalar:

# %%
sns.barplot(x='sex', y='total_bill', data=tips, estimator=np.std)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ### Countplot
#
# This is essentially the same as barplot except the estimator is explicitly counting the number of occurrences. Which is why we only pass the x value:

# %%
sns.countplot(x='sex', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# ### Boxplot
#
# boxplots are used to shown the distribution of categorical data. A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable. The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be “outliers” using a method that is a function of the inter-quartile range.

# %%
sns.boxplot(x="day", y="total_bill", data=tips, palette='rainbow')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# Can do entire dataframe with orient='h'
sns.boxplot(data=tips, palette='rainbow', orient='h')
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x="day", y="total_bill", hue="smoker", data=tips, palette="coolwarm")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Violinplot
# A violin plot plays a similar role as a box and whisker plot. It shows the distribution of quantitative data across several levels of one (or more) categorical variables such that those distributions can be compared. Unlike a box plot, in which all of the plot components correspond to actual datapoints, the violin plot features a kernel density estimation of the underlying distribution.

# %%
sns.violinplot(x="day", y="total_bill", data=tips, palette='rainbow')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day", y="total_bill", data=tips, hue='sex', palette='Set1')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day", y="total_bill", data=tips, hue='sex', split=True, palette='Set1')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Stripplot
# The **stripplot** will draw a scatterplot where one variable is categorical. A strip plot can be drawn on its own, but it is also a good complement to a box or violin plot in cases where you want to show all observations along with some representation of the underlying distribution.

# %%
sns.stripplot(x="day", y="total_bill", data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True, hue='sex', palette='Set1')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True, hue='sex', palette='Set1', dodge=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Swarmplot
# The **swarmplot** is similar to stripplot, but the points are adjusted (only along the categorical axis) so that they don’t overlap. This gives a better representation of the distribution of values, although it does not scale as well to large numbers of observations (both in terms of the ability to show all the points and in terms of the computation needed to arrange them).

# %%
sns.swarmplot(x="day", y="total_bill", data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day", y="total_bill", hue='sex', data=tips, palette="Set1", dodge=True)
# Out:
# G:\Anaconda\envs\course\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Combining Categorical Plots

# %%
sns.violinplot(x="tip", y="day", data=tips, palette='rainbow')
sns.swarmplot (x="tip", y="day", data=tips, color='black', size=3)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %% [markdown]
# ### catplot
#
# **catplot** is the most general form of a categorical plot. It can take in a **kind** parameter to adjust the plot type:

# %%
sns.catplot(x='sex', y='total_bill', data=tips, kind='bar')

# %% [markdown]
# ## Matrix Plots
#
# Matrix plots allow you to plot data as color-encoded matrices called heatmaps.
#
# Let's begin by exploring seaborn's heatmap:

# %% [markdown]
# ### Heatmap
#
# In order for a heatmap to work properly, your data should already be in a matrix form, the `sns.heatmap()` function basically just colors it in for you. For example:

# %%
# Matrix form for correlation data
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(tips.corr(), cmap='coolwarm', annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Or for the flights data:

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights.pivot_table(values='passengers', index='month', columns='year')
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
pvflights = flights.pivot_table(values='passengers', index='month', columns='year')
sns.heatmap(pvflights)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(pvflights, cmap='magma', linecolor='white', linewidths=1)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %% [markdown]
# ## Style and Color
#
# We've shown a few times how to control figure aesthetics in seaborn, but let's now go over it formally:

# %% [markdown]
# ### Styles
#
# You can set particular styles:

# %%
sns.countplot(x='sex', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.set_style('white')
sns.countplot(x='sex', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.set_style('ticks')
sns.countplot(x='sex', data=tips, palette='deep')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# ### Spine Removal

# %%
sns.countplot(x='sex', data=tips)
sns.despine()

# %%
sns.countplot(x='sex', data=tips)
sns.despine(left=True)

# %% [markdown]
# ### Size and Aspect

# %% [markdown]
# You can use matplotlib's `plt.figure(figsize=(width,height)` to change the size of most seaborn plots. We will learn more about matplotlib in the next chapter.
#
# You can control the size and aspect ratio of most seaborn grid plots by passing in parameters: *size*, and *aspect* (size refers to height and aspect refers to widht as multiple of height). For example:

# %%
# Non Grid Plot
plt.figure(figsize=(12,3))
sns.countplot(x='sex', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
# Grid Type Plot
sns.lmplot(x='total_bill', y='tip', height=3, aspect=4, data=tips)

# %% [markdown]
# ### Scale and Context
#
# The `set_context()` allows you to override default parameters:

# %%
sns.set_context('poster', font_scale=4)
sns.countplot(x='sex', data=tips, palette='coolwarm')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# ## Conclusion
#
# ### Questionaire
#  1. Which type of plots can be used to check the distribution of data?
#  2. What is difference between *bar plot* and *count plot*?
#  3. Which plot method is used to plot the correlation between columns?
#  4. What happens in spine removal?
#
# ### Further Reading
# - [5 Quick and Easy Data Visualizations in Python with Code](https://towardsdatascience.com/5-quick-and-easy-data-visualizations-in-python-with-code-a2284bae952f)
# - Check out the documentation page for more info on these topics: [link to documentation](https://stanford.edu/~mwaskom/software/seaborn/tutorial/aesthetics.html)
